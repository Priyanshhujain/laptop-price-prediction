# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/laptop_data.csv")

#df=pd.read_csv("/content/laptop_data.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB', '')

# %%
df["Weight"] = df['Weight'].str.replace('kg', '')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df["Ram"] = df["Ram"].astype("int32")
df["Weight"] = df["Weight"].astype("float32")

# %%
df["Weight"].dtype
# Out:
# dtype('float32')

# %%
import seaborn as sns

# %%
#Price Distribution of Data
sns.displot(df["Price"])

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df["Company"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.barplot(x=df["TypeName"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(df["Inches"])

# %%
sns.scatterplot(x=df["Inches"], y=df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df["ScreenResolution"].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df["Touchscreen"] = df["ScreenResolution"].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df["Touchscreen"].value_counts()
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
sns.barplot(x=df["Touchscreen"], y=df["Price"])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df["IPS"] = df["ScreenResolution"].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.tail()
# Out:
#      Company            TypeName  Inches  \
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz    4           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4           500GB HDD
#
# ...

# %%
df["IPS"].value_counts()
# Out:
# 0    938
# 1    365
# Name: IPS, dtype: int64

# %%
sns.barplot(x=df["IPS"], y=df["Price"])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
New = df["ScreenResolution"].str.split('x', n=1,expand=True)

# %%
df["X_res"] = New[0]
df["Y_res"] = New[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
#regular expression
df["X_res"] = df["X_res"].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df["X_res"] = df["X_res"].astype("int")
df["Y_res"] = df["Y_res"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
 df.corr()["Price"]
# Out:
# <ipython-input-45-870a02554510>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["Price"]
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
#ppi(pixel per inch) df["x_res"] ka square + df["y_res"] ka square and take sqaure root of both  with power of 0.5 and divided by df["inches"]
df["ppi"] = ((df["X_res"]**2) + (df["Y_res"]**2))**0.5/df["Inches"]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.corr()["Price"]
# Out:
# <ipython-input-48-870a02554510>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["Price"]
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=["Inches", "X_res", "Y_res"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df["Cpu"].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df["Cpu Name"] = df["Cpu"].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
def fetch_processor(text):
    if text == "Intel Core i7" or text == "Intel Core i5" or text == "Intel Core i3":
        return text
    else:
        if text.split()[0] == "intel":
            return "other intel processor"
        else:
            return "AMD processor"

# %%
df["Cpu brand"] = df["Cpu Name"].apply(fetch_processor)

# %%
df.head(10)
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook                            1366x768
# 6   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 7   Apple  Ultrabook                            1440x900
# 8    Asus  Ultrabook                   Full HD 1920x1080
# 9    Acer  Ultrabook         IPS Panel Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# ...

# %%
df["Cpu brand"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.barplot(x=df["Cpu brand"], y=df["Price"])
# Out:
# <Axes: xlabel='Cpu brand', ylabel='Price'>

# %%
df.drop(columns=["Cpu Name", "Cpu"], inplace=True)

# %%
df.drop(columns=["ScreenResolution"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.barplot(x=df["Ram"], y=df["Price"])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df["Memory"].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df.Memory.unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
contains_plus = df['Memory'].str.contains('\+')

# add '+  0' to the memory column where '+' sign is not present
df['Memory'] = np.where(contains_plus, df['Memory'], df['Memory'] + ' +  0xz ppt')

# %%
df.head()
# Out:
#   Company   TypeName  Ram                          Memory  \
# 0   Apple  Ultrabook    8            128GB SSD +  0xz ppt
# 1   Apple  Ultrabook    8  128GB Flash Storage +  0xz ppt
# 2      HP   Notebook    8            256GB SSD +  0xz ppt
# 3   Apple  Ultrabook   16            512GB SSD +  0xz ppt
# 4   Apple  Ultrabook    8            256GB SSD +  0xz ppt
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# ...

# %%
df.Memory.unique()
# Out:
# array(['128GB SSD +  0xz ppt', '128GB Flash Storage +  0xz ppt',
#        '256GB SSD +  0xz ppt', '512GB SSD +  0xz ppt',
#        '500GB HDD +  0xz ppt', '256GB Flash Storage +  0xz ppt',
#        '1TB HDD +  0xz ppt', '32GB Flash Storage +  0xz ppt',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage +  0xz ppt', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD +  0xz ppt',
#        '2TB HDD +  0xz ppt', '64GB SSD +  0xz ppt',
#        '1.0TB Hybrid +  0xz ppt', '512GB SSD +  1TB HDD',
#        '1TB SSD +  0xz ppt', '256GB SSD +  500GB HDD',
#        '128GB SSD +  2TB HDD', '512GB SSD +  512GB SSD',
#        '16GB SSD +  0xz ppt', '16GB Flash Storage +  0xz ppt',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD +  0xz ppt',
#        '1TB HDD +  1TB HDD', '32GB HDD +  0xz ppt', '1TB SSD +  1TB HDD',
#        '512GB Flash Storage +  0xz ppt', '128GB HDD +  0xz ppt',
# ...

# %%
df[['Memory1', 'Memory2']] = df['Memory'].str.split(' \+ ', expand=True)

# %%
df.Memory1.unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '64GB Flash Storage', '32GB SSD', '2TB HDD',
#        '64GB SSD', '1.0TB Hybrid', '1TB SSD', '16GB SSD',
#        '16GB Flash Storage', '180GB SSD', '32GB HDD',
#        '512GB Flash Storage', '128GB HDD', '240GB SSD', '8GB SSD',
#        '508GB Hybrid', '1.0TB HDD'], dtype=object)

# %%
df.Memory2.unique()
# Out:
# array([' 0xz ppt', ' 1TB HDD', ' 256GB SSD', ' 2TB HDD', ' 500GB HDD',
#        ' 512GB SSD', ' 1.0TB Hybrid'], dtype=object)

# %%
# extract the patterns using regex and create new columns
df[['Size1', 'Unit1', 'Storage1']] = df['Memory1'].str.extract(r'(\d+)([A-Za-z]+)\s+([A-Za-z ]+)')

# %%
# extract the patterns using regex and create new columns for second memory
df[['Size2', 'Unit2', 'Storage2']] = df['Memory2'].str.extract(r'(\d+)([A-Za-z]+)\s+([A-Za-z ]+)')

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price', 'Touchscreen', 'IPS', 'ppi', 'Cpu brand', 'Memory1', 'Memory2',
#        'Size1', 'Unit1', 'Storage1', 'Size2', 'Unit2', 'Storage2'],
#       dtype='object')

# %%
df[['Memory',  'Memory1',
       'Memory2', 'Size1', 'Unit1', 'Storage1', 'Size2', 'Unit2', 'Storage2']]
# Out:
#                               Memory              Memory1   Memory2 Size1  \
# 0               128GB SSD +  0xz ppt            128GB SSD   0xz ppt   128
# 1     128GB Flash Storage +  0xz ppt  128GB Flash Storage   0xz ppt   128
# 2               256GB SSD +  0xz ppt            256GB SSD   0xz ppt   256
# 3               512GB SSD +  0xz ppt            512GB SSD   0xz ppt   512
# 4               256GB SSD +  0xz ppt            256GB SSD   0xz ppt   256
# ...                              ...                  ...       ...   ...
# 1298            128GB SSD +  0xz ppt            128GB SSD   0xz ppt   128
# 1299            512GB SSD +  0xz ppt            512GB SSD   0xz ppt   512
# 1300   64GB Flash Storage +  0xz ppt   64GB Flash Storage   0xz ppt    64
# 1301              1TB HDD +  0xz ppt              1TB HDD   0xz ppt     1
# 1302            500GB HDD +  0xz ppt            500GB HDD   0xz ppt   500
#
#      Unit1       Storage1 Size2 Unit2 Storage2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-76-10829db803de>:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# <ipython-input-76-10829db803de>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName  Ram                        Memory  \
# 0   Apple  Ultrabook    8            128 SSD +  0xz ppt
# 1   Apple  Ultrabook    8  128 Flash Storage +  0xz ppt
# 2      HP   Notebook    8            256 SSD +  0xz ppt
# 3   Apple  Ultrabook   16            512 SSD +  0xz ppt
# 4   Apple  Ultrabook    8            256 SSD +  0xz ppt
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    ...  Size1 Unit1       Storage1 Size2 Unit2 Storage2 HDD  SSD Hybrid  \
# 0  ...    128    GB            SSD     0    xz      ppt   0  128      0
# ...

# %%
df["SSD"].unique()
# Out:
# array([ 128,    0,  256,  512,   32,   64, 1000, 1024,   16,  768,  180,
#         240,    8])

# %%
df.corr()["Price"]
# Out:
# <ipython-input-79-870a02554510>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()["Price"]
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price', 'Touchscreen', 'IPS', 'ppi', 'Cpu brand', 'Memory1', 'Memory2',
#        'Size1', 'Unit1', 'Storage1', 'Size2', 'Unit2', 'Storage2', 'HDD',
#        'SSD', 'Hybrid', 'Flash_Storage'],
#       dtype='object')

# %%
df.drop(columns=['Memory', 'Hybrid', 'Flash_Storage'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi  ...              Memory1  \
# 0   71378.6832            0    1  226.983005  ...            128GB SSD
# 1   47895.5232            0    0  127.677940  ...  128GB Flash Storage
# 2   30636.0000            0    0  141.211998  ...            256GB SSD
# 3  135195.3360            0    1  220.534624  ...            512GB SSD
# 4   96095.8080            0    1  226.983005  ...            256GB SSD
#
#     Memory2 Size1 Unit1       Storage1 Size2 Unit2 Storage2 HDD  SSD
# ...

# %%
df["Gpu"].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df["Gpu_brand"] = df["Gpu"].apply(lambda x:x.split()[0])

# %%
df["Gpu_brand"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu_brand, dtype: int64

# %%
# to remove arm from gpu brand column
df = df[df["Gpu_brand"] != "ARM"]

# %%
df["Gpu_brand"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu_brand, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi  ...   Memory2 Size1 Unit1  \
# 0   71378.6832            0    1  226.983005  ...   0xz ppt   128    GB
# 1   47895.5232            0    0  127.677940  ...   0xz ppt   128    GB
# 2   30636.0000            0    0  141.211998  ...   0xz ppt   256    GB
# 3  135195.3360            0    1  220.534624  ...   0xz ppt   512    GB
# 4   96095.8080            0    1  226.983005  ...   0xz ppt   256    GB
#
#         Storage1 Size2 Unit2 Storage2 HDD  SSD  Gpu_brand
# ...

# %%
sns.barplot(x=df["Gpu_brand"], y=df["Price"])
# Out:
# <Axes: xlabel='Gpu_brand', ylabel='Price'>

# %%
df.drop(columns=["Gpu"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  ...   Memory2 Size1 Unit1       Storage1 Size2  \
# 0  226.983005  Intel Core i5  ...   0xz ppt   128    GB            SSD     0
# 1  127.677940  Intel Core i5  ...   0xz ppt   128    GB  Flash Storage     0
# 2  141.211998  Intel Core i5  ...   0xz ppt   256    GB            SSD     0
# 3  220.534624  Intel Core i7  ...   0xz ppt   512    GB            SSD     0
# 4  226.983005  Intel Core i5  ...   0xz ppt   256    GB            SSD     0
#
#   Unit2 Storage2 HDD  SSD  Gpu_brand
# ...

# %%
df["OpSys"].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df["OpSys"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  ... Size1 Unit1       Storage1 Size2 Unit2  \
# 0  226.983005  Intel Core i5  ...   128    GB            SSD     0    xz
# 1  127.677940  Intel Core i5  ...   128    GB  Flash Storage     0    xz
# 2  141.211998  Intel Core i5  ...   256    GB            SSD     0    xz
# 3  220.534624  Intel Core i7  ...   512    GB            SSD     0    xz
# 4  226.983005  Intel Core i5  ...   256    GB            SSD     0    xz
#
#   Storage2 HDD  SSD  Gpu_brand                  os
# ...

# %%
df.drop(columns=["OpSys"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand              Memory1  ... Size1 Unit1       Storage1 Size2  \
# 0  Intel Core i5            128GB SSD  ...   128    GB            SSD     0
# 1  Intel Core i5  128GB Flash Storage  ...   128    GB  Flash Storage     0
# 2  Intel Core i5            256GB SSD  ...   256    GB            SSD     0
# 3  Intel Core i7            512GB SSD  ...   512    GB            SSD     0
# 4  Intel Core i5            256GB SSD  ...   256    GB            SSD     0
#
# ...

# %%
sns.barplot(x=df["os"], y=df["Price"])
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-100-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Weight', 'Price', 'Touchscreen', 'IPS',
#        'ppi', 'Cpu brand', 'Memory1', 'Memory2', 'Size1', 'Unit1', 'Storage1',
#        'Size2', 'Unit2', 'Storage2', 'HDD', 'SSD', 'Gpu_brand', 'os'],
#       dtype='object')

# %%
sns.displot(np.log(df["Price"]))

# %%
X = df.drop(columns=["Price"])
y = np.log(df["Price"])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer

# %%
ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
])
# Out:
# ColumnTransformer(transformers=[('col_tnf',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  [0, 1, 7, 10, 11])])

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand              Memory1  ... Size1 Unit1       Storage1 Size2  \
# 0  Intel Core i5            128GB SSD  ...   128    GB            SSD     0
# 1  Intel Core i5  128GB Flash Storage  ...   128    GB  Flash Storage     0
# 2  Intel Core i5            256GB SSD  ...   256    GB            SSD     0
# 3  Intel Core i7            512GB SSD  ...   512    GB            SSD     0
# 4  Intel Core i5            256GB SSD  ...   256    GB            SSD     0
#
# ...

# %%
X.head()
# Out:
#   Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34            0    0  127.677940
# 2      HP   Notebook    8    1.86            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37            0    1  226.983005
#
#        Cpu brand              Memory1   Memory2 Size1 Unit1       Storage1  \
# 0  Intel Core i5            128GB SSD   0xz ppt   128    GB            SSD
# 1  Intel Core i5  128GB Flash Storage   0xz ppt   128    GB  Flash Storage
# 2  Intel Core i5            256GB SSD   0xz ppt   256    GB            SSD
# 3  Intel Core i7            512GB SSD   0xz ppt   512    GB            SSD
# 4  Intel Core i5            256GB SSD   0xz ppt   256    GB            SSD
#
#   Size2 Unit2 Storage2  HDD  SSD Gpu_brand                  os
# 0     0    xz      ppt    0  128     Intel                 Mac
# ...

# %%
X.drop(columns=["Memory1", "Memory2", "Size1", "Size2", "Unit1", "Unit2", "Storage1", "Storage2"], inplace=True)
X_test.drop(columns=["Memory1", "Memory2", "Size1", "Size2", "Unit1", "Unit2", "Storage1", "Storage2"], inplace=True)
X_train.drop(columns=["Memory1", "Memory2", "Size1", "Size2", "Unit1", "Unit2", "Storage1", "Storage2"], inplace=True)

# %%
X.head()
# Out:
#   Company   TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34            0    0  127.677940
# 2      HP   Notebook    8    1.86            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu_brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Touchscreen  1302 non-null   int64
#  5   IPS          1302 non-null   int64
#  6   ppi          1302 non-null   float64
#  7   Cpu brand    1302 non-null   object
#  8   HDD          1302 non-null   int64
#  9   SSD          1302 non-null   int64
#  10  Gpu_brand    1302 non-null   object
#  11  os           1302 non-null   object
# dtypes: float32(1), float64(1), int32(1), int64(4), object(5)
# memory usage: 122.1+ KB

# %%
# Import label encoder
from sklearn import preprocessing


# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
X['Company']= label_encoder.fit_transform(X['Company'])

# %%
X_test['Company']= label_encoder.fit_transform(X_test['Company'])

# %%
X_test['TypeName']= label_encoder.fit_transform(X_test['TypeName'])

# %%
X_test['Cpu brand']= label_encoder.fit_transform(X_test['Cpu brand'])

# %%
X_test['Gpu_brand']= label_encoder.fit_transform(X_test['Gpu_brand'])

# %%
X_test['os']= label_encoder.fit_transform(X_test['os'])

# %%
X_test
# Out:
#       Company  TypeName  Ram  Weight  Touchscreen  IPS         ppi  Cpu brand  \
# 248         4         3    4    1.49            0    1  165.632118          2
# 555         2         3    4    2.00            0    0  100.454670          0
# 1251        4         3    4    1.86            0    0  100.454670          0
# 547         5         3    4    2.15            0    0  141.211998          2
# 885         4         0    4    1.28            1    0  165.632118          2
# ...       ...       ...  ...     ...          ...  ...         ...        ...
# 1129        4         1    8    3.35            0    1  127.335675          2
# 172         5         3    4    2.20            0    0  100.454670          0
# 322         2         3    8    2.00            0    0  157.350512          3
# 996         4         4    8    1.11            1    1  165.632118          3
# 470         4         0    8    1.29            1    1  331.264236          3
#
#        HDD  SSD  Gpu_brand  os
# ...

# %%
X_train['Company']= label_encoder.fit_transform(X_train['Company'])

# %%
X_train['TypeName']= label_encoder.fit_transform(X_train['TypeName'])

# %%
X_train['Cpu brand']= label_encoder.fit_transform(X_train['Cpu brand'])

# %%
X_train['Gpu_brand']= label_encoder.fit_transform(X_train['Gpu_brand'])

# %%
X_train['os']= label_encoder.fit_transform(X_train['os'])

# %%
# Encode labels in column 'species'.
X['TypeName']= label_encoder.fit_transform(X['TypeName'])

# %%
# Encode labels in column 'species'.
X['Cpu brand']= label_encoder.fit_transform(X['Cpu brand'])

# %%
# Encode labels in column 'species'.
X['Gpu_brand']= label_encoder.fit_transform(X['Gpu_brand'])

# %%
# Encode labels in column 'species'.
X['os']= label_encoder.fit_transform(X['os'])

# %%
X_train.head()
# Out:
#       Company  TypeName  Ram  Weight  Touchscreen  IPS         ppi  Cpu brand  \
# 183        16         3    8    2.00            0    0  100.454670          2
# 1141       11         1    8    2.40            0    0  141.211998          3
# 1049        2         2    4    1.20            0    0  135.094211          0
# 1020        4         0    4    2.08            1    1  141.211998          1
# 878         4         3    4    2.18            0    0  141.211998          2
#
#        HDD  SSD  Gpu_brand  os
# 183      0  128          1   2
# 1141  1000  128          2   2
# 1049     0    0          1   1
# 1020  1000    0          1   2
# 878   1000  128          2   2

# %%
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
])

# import the regressor
from sklearn.tree import DecisionTreeRegressor

# create a regressor object
step2 = DecisionTreeRegressor(max_depth = 8)

# fit the regressor with X and Y data
ft = step2.fit(X_train, y_train)

# %%
ft
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
y_pred = ft.predict(X_test)

# %%
print("R2 score",r2_score(y_pred,y_test))
print("MAE",mean_absolute_error(y_pred,y_test))
# Out:
# R2 score 0.7960114650405026
# MAE 0.2120677667625678

# %%
plt.figure(figsize=(12, 5))
plt.plot(range(len(y_test)),y_test,color='red')
plt.plot(range(len(y_pred)),y_pred,color='green')
plt.scatter(range(len(y_pred)), y_pred,color='red')
plt.scatter( range(len(y_test)),y_test,color='green')

# %%
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in Rupees)')
plt.ylabel('Proportion of laptops')

plt.show()
plt.close()
# Out:
# <ipython-input-137-85b810157dd1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual Value")
# <ipython-input-137-85b810157dd1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Exporting model

# %%
import pickle

# %%
pickle.dump(df,open("df.pkl","wb"))

# %%
pickle.dump(ft,open("ft.pkl","wb"))

# %%
$ pip install sklearn       # Alternative 1
$ pip install scikit-learn  # Alternative 2
